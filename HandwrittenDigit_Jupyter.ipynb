# %%
pip install tensorflow numpy matplotlib opencv-python pillow scikit-learn pyautogui
# Out:
# Requirement already satisfied: tensorflow in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (2.20.0)
# Requirement already satisfied: numpy in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (2.0.1)
# Requirement already satisfied: matplotlib in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (3.10.7)
# Requirement already satisfied: opencv-python in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (4.12.0.88)
# Requirement already satisfied: pillow in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (11.0.0)
# Requirement already satisfied: scikit-learn in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (1.7.2)
# Collecting pyautogui
#   Downloading PyAutoGUI-0.9.54.tar.gz (61 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (6.33.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (3.12.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from scikit-learn) (3.6.0)
# Collecting pymsgbox (from pyautogui)
#   Downloading pymsgbox-2.0.1-py3-none-any.whl.metadata (4.4 kB)
# Collecting pytweening>=1.0.4 (from pyautogui)
#   Downloading pytweening-1.2.0.tar.gz (171 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pyscreeze>=0.1.21 (from pyautogui)
#   Downloading pyscreeze-1.0.1.tar.gz (27 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pygetwindow>=0.0.5 (from pyautogui)
#   Downloading PyGetWindow-0.0.9.tar.gz (9.7 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting mouseinfo (from pyautogui)
#   Downloading MouseInfo-0.1.3.tar.gz (10 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Collecting pyrect (from pygetwindow>=0.0.5->pyautogui)
#   Downloading PyRect-0.2.0.tar.gz (17 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (2.1.5)
# Collecting pyperclip (from mouseinfo->pyautogui)
#   Downloading pyperclip-1.11.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rajam\anaconda3\envs\smartpricing\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Downloading pymsgbox-2.0.1-py3-none-any.whl (10.0 kB)
# Downloading pyperclip-1.11.0-py3-none-any.whl (11 kB)
# Building wheels for collected packages: pyautogui, pygetwindow, pyscreeze, pytweening, mouseinfo, pyrect
#   Building wheel for pyautogui (pyproject.toml): started
#   Building wheel for pyautogui (pyproject.toml): finished with status 'done'
#   Created wheel for pyautogui: filename=pyautogui-0.9.54-py3-none-any.whl size=37707 sha256=db0ce979b1e69e61c92d537689b1f4c476db72efdfd24cef97790ce9b6256c85
#   Stored in directory: c:\users\rajam\appdata\local\pip\cache\wheels\d9\d6\47\04075995b093ecc87c212c9a3dbd34e59456c6fe504d65c3e4
#   Building wheel for pygetwindow (pyproject.toml): started
#   Building wheel for pygetwindow (pyproject.toml): finished with status 'done'
#   Created wheel for pygetwindow: filename=pygetwindow-0.0.9-py3-none-any.whl size=11137 sha256=2ae645d56b0c9754b5c50c8344bf99299064c2b026bd7127c27857453c3d1dc2
#   Stored in directory: c:\users\rajam\appdata\local\pip\cache\wheels\b3\39\81\34dd7a2eca5f885f1f6e2796761970daf66a2d98ac1904f5f4
#   Building wheel for pyscreeze (pyproject.toml): started
#   Building wheel for pyscreeze (pyproject.toml): finished with status 'done'
#   Created wheel for pyscreeze: filename=pyscreeze-1.0.1-py3-none-any.whl size=14481 sha256=a82a7a0081fe26743f3ee6793ed2a4fc07af3dd283a79fee6c0a6a1004073175
#   Stored in directory: c:\users\rajam\appdata\local\pip\cache\wheels\cd\3a\c2\7f2839239a069aa3c9564f6777cbb29d733720ef673f104f0d
#   Building wheel for pytweening (pyproject.toml): started
#   Building wheel for pytweening (pyproject.toml): finished with status 'done'
#   Created wheel for pytweening: filename=pytweening-1.2.0-py3-none-any.whl size=8135 sha256=84a85e619cbcfe9572600e3722cf6398fdde197b80fedb4f09592e2a80dd4c4c
#   Stored in directory: c:\users\rajam\appdata\local\pip\cache\wheels\23\d5\13\4e9bdadbfe3c78e47c675e7410c0eed2fbb63c5ea6cf1b40e7
#   Building wheel for mouseinfo (pyproject.toml): started
#   Building wheel for mouseinfo (pyproject.toml): finished with status 'done'
#   Created wheel for mouseinfo: filename=mouseinfo-0.1.3-py3-none-any.whl size=10967 sha256=3230a3486f5cfbae9b7d8280439674d508eda4d219dec99c8bdfc52c9a2044f9
#   Stored in directory: c:\users\rajam\appdata\local\pip\cache\wheels\b1\9b\f3\08650eb7f00af32f07789f3c6a101e0d7fc762b9891ae843bb
#   Building wheel for pyrect (pyproject.toml): started
#   Building wheel for pyrect (pyproject.toml): finished with status 'done'
#   Created wheel for pyrect: filename=pyrect-0.2.0-py2.py3-none-any.whl size=11306 sha256=686dc696c812cf5c54212e960253079c028956bd3b1cad4ede164618e2b6e161
#   Stored in directory: c:\users\rajam\appdata\local\pip\cache\wheels\0b\1e\d7\0c74bd8f60b39c14d84e307398786002aa7ddc905927cc03c5
# Successfully built pyautogui pygetwindow pyscreeze pytweening mouseinfo pyrect
# Installing collected packages: pytweening, pyscreeze, pyrect, pyperclip, pymsgbox, pygetwindow, mouseinfo, pyautogui
#
#    ----------------------------------- ---- 7/8 [pyautogui]
#    ---------------------------------------- 8/8 [pyautogui]
#
# Successfully installed mouseinfo-0.1.3 pyautogui-0.9.54 pygetwindow-0.0.9 pymsgbox-2.0.1 pyperclip-1.11.0 pyrect-0.2.0 pyscreeze-1.0.1 pytweening-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# ================================================================
# 🧠 CONSISTENT HANDWRITTEN DIGIT RECOGNIZER (JUPYTER VERSION)
# ================================================================
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import cv2
import time
from sklearn.model_selection import train_test_split
from PIL import Image as PILImage
import pyautogui
import platform
import subprocess
import os

print("🎯 CONSISTENT Handwritten Digit Recognizer (Local Jupyter Version)")
print("=" * 60)

# ----------------------------------------------------------
# 1️⃣ Load and Preprocess MNIST Dataset
# ----------------------------------------------------------
(x_full, y_full), _ = keras.datasets.mnist.load_data()
x_full = x_full.astype("float32") / 255.0
x_full = np.expand_dims(x_full, -1)

x_train, x_test, y_train, y_test = train_test_split(
    x_full, y_full, test_size=0.2, random_state=42, stratify=y_full, shuffle=True
)

print(f"✅ Training samples: {len(x_train)}, Test samples: {len(x_test)}")

# ----------------------------------------------------------
# 2️⃣ Model Creation
# ----------------------------------------------------------
def create_consistent_model():
    model = keras.Sequential([
        layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
        layers.Conv2D(32, (3, 3), activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        layers.Flatten(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(10, activation='softmax')
    ])
    return model

# ----------------------------------------------------------
# 3️⃣ Compile and Train
# ----------------------------------------------------------
model = create_consistent_model()
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history = model.fit(
    x_train, y_train,
    batch_size=128,
    epochs=10,
    validation_split=0.1,
    verbose=1,
    callbacks=[keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)]
)

test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"\n🎯 Test Accuracy: {test_accuracy*100:.2f}%")
model.save('create_consistent_model.h5')

# ----------------------------------------------------------
# 4️⃣ Simple Preprocessing
# ----------------------------------------------------------
def simple_preprocess(image, inversion_method='auto'):
    if len(image.shape) == 3:
        image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    image = cv2.resize(image, (28, 28))
    if inversion_method == 'auto' and np.mean(image) > 127:
        image = 255 - image
    elif inversion_method == 'invert':
        image = 255 - image
    image = image.astype('float32') / 255.0
    image = np.expand_dims(image, -1)
    image = np.expand_dims(image, 0)
    return image

# ----------------------------------------------------------
# 5️⃣ Predict Digit from File
# ----------------------------------------------------------
def predict_digit_from_file(file_path):
    image = PILImage.open(file_path)
    image_array = np.array(image)
    processed = simple_preprocess(image_array, 'auto')
    pred = model.predict(processed, verbose=0)[0]
    digit = np.argmax(pred)
    confidence = np.max(pred)
    print(f"\n🧮 Predicted Digit: {digit} (Confidence: {confidence:.4f})")
    blink_capslock(digit)
    return digit, confidence

# ----------------------------------------------------------
# 6️⃣ Blink Caps Lock LED to Show Digit
# ----------------------------------------------------------
def blink_capslock(digit):
    """Blink Caps Lock LED equal to the digit value."""
    if digit == 0:
        print("Digit is 0 — not blinking.")
        return

    print(f"💡 Blinking Caps Lock {digit} times...")
    os_name = platform.system().lower()

    for _ in range(digit):
        if "windows" in os_name:
            pyautogui.press("capslock")
            time.sleep(0.3)
            pyautogui.press("capslock")
        elif "linux" in os_name:
            subprocess.run(["xdotool", "key", "Caps_Lock"])
            time.sleep(0.3)
            subprocess.run(["xdotool", "key", "Caps_Lock"])
        else:
            print("(Caps Lock control not supported on this OS)")
            break
        time.sleep(0.3)
    print("✅ Blink complete!")

# ----------------------------------------------------------
# 7️⃣ Example Usage
# ----------------------------------------------------------
# To test with an image file (e.g., "digit_5.png" on your PC):
# predict_digit_from_file("digit_5.png")
# Out:
# 🎯 CONSISTENT Handwritten Digit Recognizer (Local Jupyter Version)
# ============================================================
# ✅ Training samples: 48000, Test samples: 12000
# Epoch 1/10
# C:\Users\rajam\anaconda3\envs\smartpricing\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8963 - loss: 0.3245 - val_accuracy: 0.9800 - val_loss: 0.0667
# Epoch 2/10
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.9720 - loss: 0.0897 - val_accuracy: 0.9854 - val_loss: 0.0489
# Epoch 3/10
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9806 - loss: 0.0638 - val_accuracy: 0.9898 - val_loss: 0.0376
# Epoch 4/10
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9854 - loss: 0.0481 - val_accuracy: 0.9894 - val_loss: 0.0363
# Epoch 5/10
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9870 - loss: 0.0437 - val_accuracy: 0.9917 - val_loss: 0.0306
# Epoch 6/10
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9883 - loss: 0.0373 - val_accuracy: 0.9919 - val_loss: 0.0311
# Epoch 7/10
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9903 - loss: 0.0327 - val_accuracy: 0.9921 - val_loss: 0.0290
# Epoch 8/10
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.9904 - loss: 0.0303 - val_accuracy: 0.9921 - val_loss: 0.0287
# Epoch 9/10
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9913 - loss: 0.0275 - val_accuracy: 0.9923 - val_loss: 0.0291
# Epoch 10/10
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9921 - loss: 0.0254 - val_accuracy: 0.9923 - val_loss: 0.0281
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 🎯 Test Accuracy: 99.12%

# %%
predict_digit_from_file("IMG-20251108-WA0003.jpg")
# Out:
# 🧮 Predicted Digit: 6 (Confidence: 1.0000)
# 💡 Blinking Caps Lock 6 times...
# ✅ Blink complete!
# (np.int64(6), np.float32(0.9999827))
